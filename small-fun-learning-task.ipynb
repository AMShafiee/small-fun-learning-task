# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task
# !pip install transformers
# Out:
# /content/drive/MyDrive/Colab Notebooks/small-fun-learning-task
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 8.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 41.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 101 kB 14.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU devide not found.')
print('Found GPU at: {}'.format(device_name))

# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task/research_problem_sentence_detection
# !python train_research_problem_sentence_detection.py
# Out:
# Found GPU at: /device:GPU:0
# /content/drive/MyDrive/Colab Notebooks/small-fun-learning-task/research_problem_sentence_detection
# evaluate_research_problem_sentence_detection.py
# predict_research_problem_sentence_detection.py
# train_research_problem_sentence_detection.py
# 2022-07-17 08:00:46.297606: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Downloading: 100% 28.0/28.0 [00:00<00:00, 38.3kB/s]
# Downloading: 100% 226k/226k [00:00<00:00, 2.02MB/s]
# Downloading: 100% 455k/455k [00:00<00:00, 3.87MB/s]
# Downloading: 100% 570/570 [00:00<00:00, 720kB/s]
# train data loaded:(44160)
# validation data loaded:(11041)
# Downloading: 100% 511M/511M [00:07<00:00, 68.3MB/s]
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# ...

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU devide not found.')
print('Found GPU at: {}'.format(device_name))

# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task/research_problem_sentence_detection
# !python predict_research_problem_sentence_detection.py
# Out:
# Found GPU at: /device:GPU:0
# /content/drive/MyDrive/Colab Notebooks/small-fun-learning-task/research_problem_sentence_detection
# 2022-07-21 11:22:55.114442: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# test data loaded: (33800)
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model loaded.
#
# Predicted sentence numbers that include research problem for  constituency_parsing/0: 209;
# Predicted sentence numbers that include research problem for  constituency_parsing/1:
# ...

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU devide not found.')
print('Found GPU at: {}'.format(device_name))

# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task/research_problem_sentence_detection
# !python evaluate_research_problem_sentence_detection.py
# Out:
# Found GPU at: /device:GPU:0
# /content/drive/MyDrive/Colab Notebooks/small-fun-learning-task/research_problem_sentence_detection
# 2022-07-21 19:06:27.932915: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Downloading: 100% 28.0/28.0 [00:00<00:00, 35.5kB/s]
# Downloading: 100% 226k/226k [00:00<00:00, 931kB/s]
# Downloading: 100% 455k/455k [00:00<00:00, 1.50MB/s]
# Downloading: 100% 570/570 [00:00<00:00, 774kB/s]
# test data loaded:(33800)
# Downloading: 100% 511M/511M [00:09<00:00, 55.8MB/s]
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# ...

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task/research_problem_phrase_detection
# %ls -a
# !python train_research_problem_phrase_detection.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/small-fun-learning-task/research_problem_phrase_detection
# evaluate_research_problem_phrase_detection.py
# predict_research_problem_phrase_detection.py
# train_research_problem_phrase_detection.py
# 2022-07-08 18:00:08.625416: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# train data loaded:(249)
# validation data loaded:(63)
# All model checkpoint layers were used when initializing TFBertForTokenClassification.
#
# Some layers of TFBertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# 32/32 [==============================] - 290s 8s/step - loss: 0.2079 - accuracy: 0.9331 - val_loss: 0.1415 - val_accuracy: 0.9316
# Epoch 2/3
# ...

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU devide not found.')
print('Found GPU at: {}'.format(device_name))

# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task/research_problem_phrase_detection
# %ls -a
# !python predict_research_problem_phrase_detection.py

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/small-fun-learning-task/research_problem_phrase_detection
# %ls -a
# !python evaluate_research_problem_phrase_detection.py
